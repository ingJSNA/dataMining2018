# %%
icfes <- read.csv("./data/ICFES/01_Sin_codigos.csv", header=TRUE)
head(icfes)

dim(icfes)
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO PERIODO
# 1 TI                 COLOMBIA          F           28/08/00             20172
# 2 CC                 COLOMBIA          F           09/01/98             20172
# 3 TI                 COLOMBIA          F           22/07/00             20172
# 4 CC                 COLOMBIA          M           06/09/00             20172
# 5 TI                 COLOMBIA          M           08/12/99             20172
# 6 TI                 COLOMBIA          F           15/01/00             20172
#   ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE ESTU_TIENEETNIA
# 1 SB11201720059208 ESTUDIANTE      COLOMBIA         No
# 2 SB11201720486951 ESTUDIANTE      COLOMBIA         No
# 3 SB11201720384898 ESTUDIANTE      COLOMBIA         Si
# 4 SB11201720401962 ESTUDIANTE      COLOMBIA         Si
# 5 SB11201720350399 ESTUDIANTE      COLOMBIA         No
# 6 SB11201720561553 ESTUDIANTE      COLOMBIA         No
#   ESTU_ETNIA                 ⋯ DESEMP_SOCIALES_CIUDADANAS PUNT_INGLES
# 1                            ⋯ 3                          58
# 2                            ⋯ 1                          45
# 3 Pasto                      ⋯ 2                          56
# 4 Comunidad afrodescendiente ⋯ 2                          38
# 5                            ⋯ 1                          40
# 6                            ⋯ 3                          49
#   PERCENTIL_INGLES DESEMP_INGLES PUNT_GLOBAL PERCENTIL_GLOBAL
# 1 79               A2            304         83
# 2 38               A-            202         15
# 3 75               A1            243         43
# 4 14               A-            210         19
# 5 20               A-            190          9
# 6 55               A1            282         70
#   ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO
# 1 60.84463             NSE3                3
# 2 46.73150             NSE2                3
# 3 32.54766             NSE1                1
# 4 38.25015             NSE1                2
# 5 50.27315             NSE2                2
# 6 25.04696             NSE1                2
#   ESTU_ESTADOINVESTIGACION
# 1 PUBLICAR
# 2 PUBLICAR
# 3 PUBLICAR
# 4 PUBLICAR
# 5 PUBLICAR
# 6 PUBLICAR
# [1] 559253     71

# %%
Mode <- function(x) {
  ux <- unique(x)
  ux[which.max(tabulate(match(x, ux)))]
}

# Defining the function, remove NA values by default
my.summary <- function(x, na.rm=TRUE){
  result <- c(Mean = mean(x, na.rm=na.rm),
              Median = median(x, na.rm=na.rm),
              #Var = var(x, na.rm=na.rm),
              SD = sd(x, na.rm=na.rm),
              Min = min(x, na.rm=na.rm),
              Max = max(x, na.rm=na.rm),
              Count = length(x))
    result <- round(result, digits=3)
}

# Defining the function, remove NA values by default
nominal.summary <- function(x, na.rm=TRUE){
  result <- c(Mode = as.character(Mode(x)), 
              occurrence_ratio = round(length(which(x == Mode(x))) / length(x), digits=3))
}

# Identifying numeric columns
ind <- sapply(icfes, is.numeric)
# Applying the summary function to numeric columns only
sapply(icfes[, ind], my.summary)

summarydata <- sapply(icfes[, !ind], nominal.summary)

mydata <- sapply(icfes[, ind], nominal.summary)

summarydata
# Out:
#        PERIODO    COLE_COD_DANE_ESTABLECIMIENTO COLE_COD_DANE_SEDE
# Mean    20171.977 207884231287                  208391162855
# Median  20172.000 176000000000                  176000000000
# SD          0.151  95416706598                   96085479413
# Min     20171.000 105000000000                  105000000000
# Max     20172.000 855000000000                  855000000000
# Count  559253.000       559253                        559253
#        PUNT_LECTURA_CRITICA PERCENTIL_LECTURA_CRITICA DESEMP_LECTURA_CRITICA
# Mean       53.399               50.478                     2.693
# Median     53.000               51.000                     3.000
# SD          9.889               28.895                     0.713
# Min         0.000                1.000                     1.000
# Max       100.000              100.000                     4.000
# Count  559253.000           559253.000                559253.000
#        PUNT_MATEMATICAS PERCENTIL_MATEMATICAS DESEMP_MATEMATICAS
# Mean       50.348           50.490                 2.421
# Median     50.000           51.000                 2.000
# SD         12.156           28.886                 0.764
# Min         0.000            1.000                 1.000
# Max       100.000          100.000                 4.000
# Count  559253.000       559253.000            559253.000
#        PUNT_C_NATURALES ⋯ DESEMP_C_NATURALES PUNT_SOCIALES_CIUDADANAS
# Mean       51.487       ⋯      2.228             50.498
# Median     51.000       ⋯      2.000             50.000
# SD         10.201       ⋯      0.737             11.264
# Min         0.000       ⋯      1.000              0.000
# Max       100.000       ⋯      4.000            100.000
# Count  559253.000       ⋯ 559253.000         559253.000
#        PERCENTIL_SOCIALES_CIUDADANAS DESEMP_SOCIALES_CIUDADANAS PUNT_INGLES
# Mean       50.504                         2.170                     49.993
# Median     51.000                         2.000                     48.000
# SD         28.863                         0.794                     11.994
# Min         1.000                         1.000                      0.000
# Max       100.000                         4.000                    100.000
# Count  559253.000                    559253.000                 559253.000
#        PERCENTIL_INGLES PUNT_GLOBAL PERCENTIL_GLOBAL ESTU_INSE_INDIVIDUAL
# Mean       50.549          256.611      50.379           50.639
# Median     51.000          254.000      50.000           50.067
# SD         28.845           49.340      28.886            9.309
# Min         1.000            0.000       1.000           14.414
# Max       100.000          476.000     100.000           84.395
# Count  559253.000       559253.000  559253.000       559253.000
#        ESTU_NSE_ESTABLECIMIENTO
# Mean        2.365
# Median      2.000
# SD          0.719
# Min         1.000
# Max         4.000
# Count  559253.000
#                  ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO
# Mode             TI                 COLOMBIA          F
# occurrence_ratio 0.812              0.999             0.545
#                  ESTU_FECHANACIMIENTO ESTU_CONSECUTIVO ESTU_ESTUDIANTE
# Mode             10/10/00             SB11201720059208 ESTUDIANTE
# occurrence_ratio 0.002                0                1
#                  ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_ETNIA ESTU_DEPTO_RESIDE
# Mode             COLOMBIA         No                         BOGOTA
# occurrence_ratio 0.999            0.936           0.942      0.165
#                  ⋯ COLE_AREA_UBICACION COLE_JORNADA COLE_MCPIO_UBICACION
# Mode             ⋯ URBANO              MA\x84ANA    BOGOT\xe7 D.C.
# occurrence_ratio ⋯ 0.85                0.493        0.163
#                  COLE_DEPTO_UBICACION ESTU_PRIVADO_LIBERTAD
# Mode             BOGOTA               N
# occurrence_ratio 0.163                0.977
#                  ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION DESEMP_INGLES
# Mode             BOGOT\xe7 D.C.          BOGOTA                  A-
# occurrence_ratio 0.165                   0.165                   0.483
#                  ESTU_NSE_INDIVIDUAL ESTU_ESTADOINVESTIGACION
# Mode             NSE2                PUBLICAR
# occurrence_ratio 0.399               0.999

# %%
dim(summarydata)

summarydata[c(1,2), c(1:50)]
# Out:
# [1]  2 50
#                  ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO
# Mode             TI                 COLOMBIA          F
# occurrence_ratio 0.812              0.999             0.545
#                  ESTU_FECHANACIMIENTO ESTU_CONSECUTIVO ESTU_ESTUDIANTE
# Mode             10/10/00             SB11201720059208 ESTUDIANTE
# occurrence_ratio 0.002                0                1
#                  ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_ETNIA ESTU_DEPTO_RESIDE
# Mode             COLOMBIA         No                         BOGOTA
# occurrence_ratio 0.999            0.936           0.942      0.165
#                  ⋯ COLE_AREA_UBICACION COLE_JORNADA COLE_MCPIO_UBICACION
# Mode             ⋯ URBANO              MA\x84ANA    BOGOT\xe7 D.C.
# occurrence_ratio ⋯ 0.85                0.493        0.163
#                  COLE_DEPTO_UBICACION ESTU_PRIVADO_LIBERTAD
# Mode             BOGOTA               N
# occurrence_ratio 0.163                0.977
#                  ESTU_MCPIO_PRESENTACION ESTU_DEPTO_PRESENTACION DESEMP_INGLES
# Mode             BOGOT\xe7 D.C.          BOGOTA                  A-
# occurrence_ratio 0.165                   0.165                   0.483
#                  ESTU_NSE_INDIVIDUAL ESTU_ESTADOINVESTIGACION
# Mode             NSE2                PUBLICAR
# occurrence_ratio 0.399               0.999

# %%
# Correlation
print("***  Correlation ***")
correlation <- cor(icfes[, ind])
round(correlation, digits=3)
# Out:
# [1] "***  Correlation ***"
#                               PERIODO COLE_COD_DANE_ESTABLECIMIENTO
# PERIODO                        1.000  -0.242
# COLE_COD_DANE_ESTABLECIMIENTO -0.242   1.000
# COLE_COD_DANE_SEDE            -0.240   0.987
# PUNT_LECTURA_CRITICA          -0.139   0.083
# PERCENTIL_LECTURA_CRITICA     -0.068   0.062
# DESEMP_LECTURA_CRITICA        -0.126   0.076
# PUNT_MATEMATICAS              -0.153   0.086
# PERCENTIL_MATEMATICAS         -0.071   0.058
# DESEMP_MATEMATICAS            -0.133   0.068
# PUNT_C_NATURALES              -0.171   0.094
# PERCENTIL_C_NATURALES         -0.070   0.062
# DESEMP_C_NATURALES            -0.156   0.084
# PUNT_SOCIALES_CIUDADANAS      -0.157   0.101
# PERCENTIL_SOCIALES_CIUDADANAS -0.064   0.072
# DESEMP_SOCIALES_CIUDADANAS    -0.146   0.095
# PUNT_INGLES                   -0.256   0.177
# PERCENTIL_INGLES              -0.073   0.103
# PUNT_GLOBAL                   -0.181   0.109
# PERCENTIL_GLOBAL              -0.073   0.070
# ESTU_INSE_INDIVIDUAL              NA      NA
# ESTU_NSE_ESTABLECIMIENTO          NA      NA
#                               COLE_COD_DANE_SEDE PUNT_LECTURA_CRITICA
# PERIODO                       -0.240             -0.139
# COLE_COD_DANE_ESTABLECIMIENTO  0.987              0.083
# COLE_COD_DANE_SEDE             1.000              0.080
# PUNT_LECTURA_CRITICA           0.080              1.000
# PERCENTIL_LECTURA_CRITICA      0.059              0.982
# DESEMP_LECTURA_CRITICA         0.074              0.913
# PUNT_MATEMATICAS               0.084              0.746
# PERCENTIL_MATEMATICAS          0.056              0.737
# DESEMP_MATEMATICAS             0.066              0.686
# PUNT_C_NATURALES               0.092              0.753
# PERCENTIL_C_NATURALES          0.061              0.745
# DESEMP_C_NATURALES             0.082              0.694
# PUNT_SOCIALES_CIUDADANAS       0.099              0.804
# PERCENTIL_SOCIALES_CIUDADANAS  0.070              0.796
# DESEMP_SOCIALES_CIUDADANAS     0.093              0.752
# PUNT_INGLES                    0.175              0.663
# PERCENTIL_INGLES               0.100              0.644
# PUNT_GLOBAL                    0.107              0.897
# PERCENTIL_GLOBAL               0.068              0.885
# ESTU_INSE_INDIVIDUAL              NA                 NA
# ESTU_NSE_ESTABLECIMIENTO          NA                 NA
#                               PERCENTIL_LECTURA_CRITICA DESEMP_LECTURA_CRITICA
# PERIODO                       -0.068                    -0.126
# COLE_COD_DANE_ESTABLECIMIENTO  0.062                     0.076
# COLE_COD_DANE_SEDE             0.059                     0.074
# PUNT_LECTURA_CRITICA           0.982                     0.913
# PERCENTIL_LECTURA_CRITICA      1.000                     0.900
# DESEMP_LECTURA_CRITICA         0.900                     1.000
# PUNT_MATEMATICAS               0.737                     0.683
# PERCENTIL_MATEMATICAS          0.742                     0.675
# DESEMP_MATEMATICAS             0.680                     0.628
# PUNT_C_NATURALES               0.741                     0.688
# PERCENTIL_C_NATURALES          0.750                     0.682
# DESEMP_C_NATURALES             0.685                     0.632
# PUNT_SOCIALES_CIUDADANAS       0.796                     0.736
# PERCENTIL_SOCIALES_CIUDADANAS  0.806                     0.730
# DESEMP_SOCIALES_CIUDADANAS     0.746                     0.686
# PUNT_INGLES                    0.641                     0.606
# PERCENTIL_INGLES               0.647                     0.590
# PUNT_GLOBAL                    0.883                     0.820
# PERCENTIL_GLOBAL               0.896                     0.811
# ESTU_INSE_INDIVIDUAL              NA                        NA
# ESTU_NSE_ESTABLECIMIENTO          NA                        NA
#                               PUNT_MATEMATICAS PERCENTIL_MATEMATICAS
# PERIODO                       -0.153           -0.071
# COLE_COD_DANE_ESTABLECIMIENTO  0.086            0.058
# COLE_COD_DANE_SEDE             0.084            0.056
# PUNT_LECTURA_CRITICA           0.746            0.737
# PERCENTIL_LECTURA_CRITICA      0.737            0.742
# DESEMP_LECTURA_CRITICA         0.683            0.675
# PUNT_MATEMATICAS               1.000            0.983
# PERCENTIL_MATEMATICAS          0.983            1.000
# DESEMP_MATEMATICAS             0.920            0.912
# PUNT_C_NATURALES               0.805            0.790
# PERCENTIL_C_NATURALES          0.794            0.800
# DESEMP_C_NATURALES             0.741            0.729
# PUNT_SOCIALES_CIUDADANAS       0.760            0.749
# PERCENTIL_SOCIALES_CIUDADANAS  0.749            0.755
# DESEMP_SOCIALES_CIUDADANAS     0.710            0.701
# PUNT_INGLES                    0.670            0.641
# PERCENTIL_INGLES               0.649            0.649
# PUNT_GLOBAL                    0.912            0.895
# PERCENTIL_GLOBAL               0.897            0.908
# ESTU_INSE_INDIVIDUAL              NA               NA
# ESTU_NSE_ESTABLECIMIENTO          NA               NA
#                               DESEMP_MATEMATICAS PUNT_C_NATURALES ⋯
# PERIODO                       -0.133             -0.171           ⋯
# COLE_COD_DANE_ESTABLECIMIENTO  0.068              0.094           ⋯
# COLE_COD_DANE_SEDE             0.066              0.092           ⋯
# PUNT_LECTURA_CRITICA           0.686              0.753           ⋯
# PERCENTIL_LECTURA_CRITICA      0.680              0.741           ⋯
# DESEMP_LECTURA_CRITICA         0.628              0.688           ⋯
# PUNT_MATEMATICAS               0.920              0.805           ⋯
# PERCENTIL_MATEMATICAS          0.912              0.790           ⋯
# DESEMP_MATEMATICAS             1.000              0.735           ⋯
# PUNT_C_NATURALES               0.735              1.000           ⋯
# PERCENTIL_C_NATURALES          0.730              0.980           ⋯
# DESEMP_C_NATURALES             0.680              0.919           ⋯
# PUNT_SOCIALES_CIUDADANAS       0.695              0.800           ⋯
# PERCENTIL_SOCIALES_CIUDADANAS  0.689              0.786           ⋯
# DESEMP_SOCIALES_CIUDADANAS     0.650              0.747           ⋯
# PUNT_INGLES                    0.601              0.686           ⋯
# PERCENTIL_INGLES               0.592              0.660           ⋯
# PUNT_GLOBAL                    0.835              0.916           ⋯
# PERCENTIL_GLOBAL               0.830              0.898           ⋯
# ESTU_INSE_INDIVIDUAL              NA                 NA           ⋯
# ESTU_NSE_ESTABLECIMIENTO          NA                 NA           ⋯
#                               DESEMP_C_NATURALES PUNT_SOCIALES_CIUDADANAS
# PERIODO                       -0.156             -0.157
# COLE_COD_DANE_ESTABLECIMIENTO  0.084              0.101
# COLE_COD_DANE_SEDE             0.082              0.099
# PUNT_LECTURA_CRITICA           0.694              0.804
# PERCENTIL_LECTURA_CRITICA      0.685              0.796
# DESEMP_LECTURA_CRITICA         0.632              0.736
# PUNT_MATEMATICAS               0.741              0.760
# PERCENTIL_MATEMATICAS          0.729              0.749
# DESEMP_MATEMATICAS             0.680              0.695
# PUNT_C_NATURALES               0.919              0.800
# PERCENTIL_C_NATURALES          0.906              0.790
# DESEMP_C_NATURALES             1.000              0.737
# PUNT_SOCIALES_CIUDADANAS       0.737              1.000
# PERCENTIL_SOCIALES_CIUDADANAS  0.726              0.981
# DESEMP_SOCIALES_CIUDADANAS     0.691              0.930
# PUNT_INGLES                    0.628              0.675
# PERCENTIL_INGLES               0.608              0.649
# PUNT_GLOBAL                    0.843              0.919
# PERCENTIL_GLOBAL               0.830              0.904
# ESTU_INSE_INDIVIDUAL              NA                 NA
# ESTU_NSE_ESTABLECIMIENTO          NA                 NA
#                               PERCENTIL_SOCIALES_CIUDADANAS
# PERIODO                       -0.064
# COLE_COD_DANE_ESTABLECIMIENTO  0.072
# COLE_COD_DANE_SEDE             0.070
# PUNT_LECTURA_CRITICA           0.796
# PERCENTIL_LECTURA_CRITICA      0.806
# DESEMP_LECTURA_CRITICA         0.730
# PUNT_MATEMATICAS               0.749
# PERCENTIL_MATEMATICAS          0.755
# DESEMP_MATEMATICAS             0.689
# PUNT_C_NATURALES               0.786
# PERCENTIL_C_NATURALES          0.798
# DESEMP_C_NATURALES             0.726
# PUNT_SOCIALES_CIUDADANAS       0.981
# PERCENTIL_SOCIALES_CIUDADANAS  1.000
# DESEMP_SOCIALES_CIUDADANAS     0.920
# PUNT_INGLES                    0.645
# PERCENTIL_INGLES               0.650
# PUNT_GLOBAL                    0.903
# PERCENTIL_GLOBAL               0.917
# ESTU_INSE_INDIVIDUAL              NA
# ESTU_NSE_ESTABLECIMIENTO          NA
#                               DESEMP_SOCIALES_CIUDADANAS PUNT_INGLES
# PERIODO                       -0.146                     -0.256
# COLE_COD_DANE_ESTABLECIMIENTO  0.095                      0.177
# COLE_COD_DANE_SEDE             0.093                      0.175
# PUNT_LECTURA_CRITICA           0.752                      0.663
# PERCENTIL_LECTURA_CRITICA      0.746                      0.641
# DESEMP_LECTURA_CRITICA         0.686                      0.606
# PUNT_MATEMATICAS               0.710                      0.670
# PERCENTIL_MATEMATICAS          0.701                      0.641
# DESEMP_MATEMATICAS             0.650                      0.601
# PUNT_C_NATURALES               0.747                      0.686
# PERCENTIL_C_NATURALES          0.740                      0.657
# DESEMP_C_NATURALES             0.691                      0.628
# PUNT_SOCIALES_CIUDADANAS       0.930                      0.675
# PERCENTIL_SOCIALES_CIUDADANAS  0.920                      0.645
# DESEMP_SOCIALES_CIUDADANAS     1.000                      0.632
# PUNT_INGLES                    0.632                      1.000
# PERCENTIL_INGLES               0.608                      0.945
# PUNT_GLOBAL                    0.858                      0.779
# PERCENTIL_GLOBAL               0.847                      0.737
# ESTU_INSE_INDIVIDUAL              NA                         NA
# ESTU_NSE_ESTABLECIMIENTO          NA                         NA
#                               PERCENTIL_INGLES PUNT_GLOBAL PERCENTIL_GLOBAL
# PERIODO                       -0.073           -0.181      -0.073
# COLE_COD_DANE_ESTABLECIMIENTO  0.103            0.109       0.070
# COLE_COD_DANE_SEDE             0.100            0.107       0.068
# PUNT_LECTURA_CRITICA           0.644            0.897       0.885
# PERCENTIL_LECTURA_CRITICA      0.647            0.883       0.896
# DESEMP_LECTURA_CRITICA         0.590            0.820       0.811
# PUNT_MATEMATICAS               0.649            0.912       0.897
# PERCENTIL_MATEMATICAS          0.649            0.895       0.908
# DESEMP_MATEMATICAS             0.592            0.835       0.830
# PUNT_C_NATURALES               0.660            0.916       0.898
# PERCENTIL_C_NATURALES          0.664            0.901       0.914
# DESEMP_C_NATURALES             0.608            0.843       0.830
# PUNT_SOCIALES_CIUDADANAS       0.649            0.919       0.904
# PERCENTIL_SOCIALES_CIUDADANAS  0.650            0.903       0.917
# DESEMP_SOCIALES_CIUDADANAS     0.608            0.858       0.847
# PUNT_INGLES                    0.945            0.779       0.737
# PERCENTIL_INGLES               1.000            0.751       0.751
# PUNT_GLOBAL                    0.751            1.000       0.981
# PERCENTIL_GLOBAL               0.751            0.981       1.000
# ESTU_INSE_INDIVIDUAL              NA               NA          NA
# ESTU_NSE_ESTABLECIMIENTO          NA               NA          NA
#                               ESTU_INSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO
# PERIODO                       NA                   NA
# COLE_COD_DANE_ESTABLECIMIENTO NA                   NA
# COLE_COD_DANE_SEDE            NA                   NA
# PUNT_LECTURA_CRITICA          NA                   NA
# PERCENTIL_LECTURA_CRITICA     NA                   NA
# DESEMP_LECTURA_CRITICA        NA                   NA
# PUNT_MATEMATICAS              NA                   NA
# PERCENTIL_MATEMATICAS         NA                   NA
# DESEMP_MATEMATICAS            NA                   NA
# PUNT_C_NATURALES              NA                   NA
# PERCENTIL_C_NATURALES         NA                   NA
# DESEMP_C_NATURALES            NA                   NA
# PUNT_SOCIALES_CIUDADANAS      NA                   NA
# PERCENTIL_SOCIALES_CIUDADANAS NA                   NA
# DESEMP_SOCIALES_CIUDADANAS    NA                   NA
# PUNT_INGLES                   NA                   NA
# PERCENTIL_INGLES              NA                   NA
# PUNT_GLOBAL                   NA                   NA
# PERCENTIL_GLOBAL              NA                   NA
# ESTU_INSE_INDIVIDUAL           1                   NA
# ESTU_NSE_ESTABLECIMIENTO      NA                    1

# %%
# Combine multiple plots
par(mfrow=c(2,2))

for(i in names(icfes[, ind])){
  hist(icfes[[i]], main=i)
}

# Histograms and density plots
hist(icfes$COLE_COD_DANE_ESTABLECIMIENTO, breaks=20, main="COLE_COD_DANE_ESTABLECIMIENTO")
plot(density(icfes$COLE_COD_DANE_ESTABLECIMIENTO), main="COLE_COD_DANE_ESTABLECIMIENTO")

# %%
# Combine multiple plots
par(mfrow=c(3,2))

for(i in names(icfes[, ind])){
  boxplot(icfes[[i]], main=i)
}
