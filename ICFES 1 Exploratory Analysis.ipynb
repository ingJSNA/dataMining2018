# %%
icfes <- read.csv("./data/ICFES/icfes.csv", header=TRUE)
head(icfes)

dim(icfes)
# Out:
#   COLE_AREA_UBICACION COLE_BILINGUE COLE_CALENDARIO COLE_CARACTER
# 1 URBANO              N             B               TÉCNICO/ACADÉMICO
# 2 URBANO                            B
# 3 URBANO              S             B               ACADÉMICO
# 4 URBANO              S             B               ACADÉMICO
# 5 URBANO              S             B               ACADÉMICO
# 6 URBANO              S             B               ACADÉMICO
#   COLE_DEPTO_UBICACION COLE_GENERO COLE_JORNADA COLE_MCPIO_UBICACION
# 1 VALLE                MIXTO                    CALI
# 2 CAUCA                MIXTO                    POPAYAN
# 3 VALLE                MIXTO                    CALI
# 4 VALLE                MIXTO                    CALI
# 5 VALLE                MIXTO                    CALI
# 6 VALLE                MIXTO                    CALI
#   COLE_NATURALEZA COLE_NOMBRE_ESTABLECIMIENTO        ⋯
# 1 NO OFICIAL      COLEGIO PARROQIAL SANTIAGO APOSTOL ⋯
# 2 NO OFICIAL      COLEGIO CESCO BILINGÜE             ⋯
# 3 NO OFICIAL      COL BOLIVAR                        ⋯
# 4 NO OFICIAL      COL BOLIVAR                        ⋯
# 5 NO OFICIAL      COL BOLIVAR                        ⋯
# 6 NO OFICIAL      COL BOLIVAR                        ⋯
#   PERCENTIL_LECTURA_CRITICA PERCENTIL_MATEMATICAS PERCENTIL_SOCIALES_CIUDADANAS
# 1 15                         4                      1
# 2 78                        62                     85
# 3 91                        99                     76
# 4 96                        96                    100
# 5 38                        35                     63
# 6 78                        95                     89
#   PERIODO PUNT_C_NATURALES PUNT_GLOBAL PUNT_INGLES PUNT_LECTURA_CRITICA
# 1 20171   35               177          45         44
# 2 20171   66               326          55         67
# 3 20171   70               378         100         72
# 4 20171   72               389          85         75
# 5 20171   52               281          80         54
# 6 20171   74               369          86         67
#   PUNT_MATEMATICAS PUNT_SOCIALES_CIUDADANAS
# 1 31               28
# 2 61               70
# 3 86               66
# 4 79               83
# 5 50               61
# 6 78               72
# [1] 559253     79

# %%
Mode <- function(x) {
  ux <- unique(x)
  ux[which.max(tabulate(match(x, ux)))]
}

# Defining the function, remove NA values by default
my.summary <- function(x, na.rm=TRUE){
  result <- c(Mean = mean(x, na.rm=na.rm),
              Median = median(x, na.rm=na.rm),
              #Var = var(x, na.rm=na.rm),
              SD = sd(x, na.rm=na.rm),
              Min = min(x, na.rm=na.rm),
              Max = max(x, na.rm=na.rm),
              Count = length(x))
    result <- round(result, digits=3)
}

# Defining the function, remove NA values by default
nominal.summary <- function(x, na.rm=TRUE){
  result <- c(Mode = as.character(Mode(x)), 
              occurrence_ratio = round(length(which(x == Mode(x))) / length(x), digits=3))
}

# Identifying numeric columns
ind <- sapply(icfes, is.numeric)
# Applying the summary function to numeric columns only
sapply(icfes[, ind], my.summary)

summarydata <- sapply(icfes[, !ind], nominal.summary)

mydata <- sapply(icfes[, ind], nominal.summary)

summarydata
# Out:
#        DESEMP_C_NATURALES DESEMP_LECTURA_CRITICA DESEMP_MATEMATICAS
# Mean        2.228              2.693                  2.421
# Median      2.000              3.000                  2.000
# SD          0.737              0.713                  0.764
# Min         1.000              1.000                  1.000
# Max         4.000              4.000                  4.000
# Count  559253.000         559253.000             559253.000
#        DESEMP_SOCIALES_CIUDADANAS ESTU_INSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO
# Mean        2.170                     50.639                2.365
# Median      2.000                     50.067                2.000
# SD          0.794                      9.309                0.719
# Min         1.000                     14.414                1.000
# Max         4.000                     84.395                4.000
# Count  559253.000                 559253.000           559253.000
#        PERCENTIL_C_NATURALES PERCENTIL_GLOBAL PERCENTIL_INGLES
# Mean       50.527                50.379           50.549
# Median     51.000                50.000           51.000
# SD         28.864                28.886           28.845
# Min         1.000                 1.000            1.000
# Max       100.000               100.000          100.000
# Count  559253.000            559253.000       559253.000
#        PERCENTIL_LECTURA_CRITICA PERCENTIL_MATEMATICAS
# Mean       50.478                    50.490
# Median     51.000                    51.000
# SD         28.895                    28.886
# Min         1.000                     1.000
# Max       100.000                   100.000
# Count  559253.000                559253.000
#        PERCENTIL_SOCIALES_CIUDADANAS PERIODO    PUNT_C_NATURALES PUNT_GLOBAL
# Mean       50.504                     20171.977     51.487          256.611
# Median     51.000                     20172.000     51.000          254.000
# SD         28.863                         0.151     10.201           49.340
# Min         1.000                     20171.000      0.000            0.000
# Max       100.000                     20172.000    100.000          476.000
# Count  559253.000                    559253.000 559253.000       559253.000
#        PUNT_INGLES PUNT_LECTURA_CRITICA PUNT_MATEMATICAS
# Mean       49.993      53.399               50.348
# Median     48.000      53.000               50.000
# SD         11.994       9.889               12.156
# Min         0.000       0.000                0.000
# Max       100.000     100.000              100.000
# Count  559253.000  559253.000           559253.000
#        PUNT_SOCIALES_CIUDADANAS
# Mean       50.498
# Median     50.000
# SD         11.264
# Min         0.000
# Max       100.000
# Count  559253.000
#                  COLE_AREA_UBICACION COLE_BILINGUE COLE_CALENDARIO
# Mode             URBANO              N             A
# occurrence_ratio 0.85                0.841         0.97
#                  COLE_CARACTER COLE_DEPTO_UBICACION COLE_GENERO COLE_JORNADA
# Mode             ACADÉMICO     BOGOTA               MIXTO       MAÑANA
# occurrence_ratio 0.539         0.163                0.963       0.493
#                  COLE_MCPIO_UBICACION COLE_NATURALEZA
# Mode             BOGOTÁ D.C.          OFICIAL
# occurrence_ratio 0.163                0.736
#                  COLE_NOMBRE_ESTABLECIMIENTO ⋯ FAMI_TIENEINTERNET
# Mode             INST EDUC CEFA              ⋯
# occurrence_ratio 0.002                       ⋯ 0.977
#                  FAMI_TIENELAVADORA FAMI_TIENEMOTOCICLETA FAMI_TIENESERVICIOTV
# Mode             Si                 No                    Si
# occurrence_ratio 0.711              0.586                 0.691
#                  FAMI_TIENE_CONSOLAVIDEOJUEGOS FAMI_TIENE_SERVICIOTV
# Mode
# occurrence_ratio 0.977                         0.977
#                  FAMI_TRABAJOLABORMADRE
# Mode             Trabaja en el hogar, no trabaja o estudia
# occurrence_ratio 0.406
#                  FAMI_TRABAJOLABORPADRE              FAMI_TRABAJOLABOR_MADRE
# Mode             Es agricultor, pesquero o jornalero
# occurrence_ratio 0.139                               0.977
#                  FAMI_TRABAJOLABOR_PADRE
# Mode
# occurrence_ratio 0.977

# %%
dim(summarydata)

summarydata[c(1,2), c(1:50)]
# Out:
# [1]  2 60
#                  COLE_AREA_UBICACION COLE_BILINGUE COLE_CALENDARIO
# Mode             URBANO              N             A
# occurrence_ratio 0.85                0.841         0.97
#                  COLE_CARACTER COLE_DEPTO_UBICACION COLE_GENERO COLE_JORNADA
# Mode             ACADÉMICO     BOGOTA               MIXTO       MAÑANA
# occurrence_ratio 0.539         0.163                0.963       0.493
#                  COLE_MCPIO_UBICACION COLE_NATURALEZA
# Mode             BOGOTÁ D.C.          OFICIAL
# occurrence_ratio 0.163                0.736
#                  COLE_NOMBRE_ESTABLECIMIENTO ⋯
# Mode             INST EDUC CEFA              ⋯
# occurrence_ratio 0.002                       ⋯
#                  FAMI_EDUCACIONPADRE                FAMI_ESTRATOVIVIENDA
# Mode             Secundaria (Bachillerato) completa Estrato 2
# occurrence_ratio 0.201                              0.34
#                  FAMI_NUMLIBROS FAMI_PERSONASHOGAR FAMI_SITUACIONECONOMICA
# Mode             0 A 10 LIBROS  3 a 4              Igual
# occurrence_ratio 0.395          0.466              0.59
#                  FAMI_SITUACION_ECONOMICA FAMI_TIENEAUTOMOVIL
# Mode                                      No
# occurrence_ratio 0.977                    0.749
#                  FAMI_TIENECOMPUTADOR FAMI_TIENECONSOLAVIDEOJUEGOS
# Mode             Si                   No
# occurrence_ratio 0.567                0.753
#                  FAMI_TIENEHORNOMICROOGAS
# Mode             No
# occurrence_ratio 0.531

# %%
# Correlation
print("***  Correlation ***")
correlation <- cor(icfes[, ind])
round(correlation, digits=3)
# Out:
# [1] "***  Correlation ***"
#                               DESEMP_C_NATURALES DESEMP_LECTURA_CRITICA
# DESEMP_C_NATURALES             1.000              0.632
# DESEMP_LECTURA_CRITICA         0.632              1.000
# DESEMP_MATEMATICAS             0.680              0.628
# DESEMP_SOCIALES_CIUDADANAS     0.691              0.686
# ESTU_INSE_INDIVIDUAL              NA                 NA
# ESTU_NSE_ESTABLECIMIENTO          NA                 NA
# PERCENTIL_C_NATURALES          0.906              0.682
# PERCENTIL_GLOBAL               0.830              0.811
# PERCENTIL_INGLES               0.608              0.590
# PERCENTIL_LECTURA_CRITICA      0.685              0.900
# PERCENTIL_MATEMATICAS          0.729              0.675
# PERCENTIL_SOCIALES_CIUDADANAS  0.726              0.730
# PERIODO                       -0.156             -0.126
# PUNT_C_NATURALES               0.919              0.688
# PUNT_GLOBAL                    0.843              0.820
# PUNT_INGLES                    0.628              0.606
# PUNT_LECTURA_CRITICA           0.694              0.913
# PUNT_MATEMATICAS               0.741              0.683
# PUNT_SOCIALES_CIUDADANAS       0.737              0.736
#                               DESEMP_MATEMATICAS DESEMP_SOCIALES_CIUDADANAS
# DESEMP_C_NATURALES             0.680              0.691
# DESEMP_LECTURA_CRITICA         0.628              0.686
# DESEMP_MATEMATICAS             1.000              0.650
# DESEMP_SOCIALES_CIUDADANAS     0.650              1.000
# ESTU_INSE_INDIVIDUAL              NA                 NA
# ESTU_NSE_ESTABLECIMIENTO          NA                 NA
# PERCENTIL_C_NATURALES          0.730              0.740
# PERCENTIL_GLOBAL               0.830              0.847
# PERCENTIL_INGLES               0.592              0.608
# PERCENTIL_LECTURA_CRITICA      0.680              0.746
# PERCENTIL_MATEMATICAS          0.912              0.701
# PERCENTIL_SOCIALES_CIUDADANAS  0.689              0.920
# PERIODO                       -0.133             -0.146
# PUNT_C_NATURALES               0.735              0.747
# PUNT_GLOBAL                    0.835              0.858
# PUNT_INGLES                    0.601              0.632
# PUNT_LECTURA_CRITICA           0.686              0.752
# PUNT_MATEMATICAS               0.920              0.710
# PUNT_SOCIALES_CIUDADANAS       0.695              0.930
#                               ESTU_INSE_INDIVIDUAL ESTU_NSE_ESTABLECIMIENTO
# DESEMP_C_NATURALES            NA                   NA
# DESEMP_LECTURA_CRITICA        NA                   NA
# DESEMP_MATEMATICAS            NA                   NA
# DESEMP_SOCIALES_CIUDADANAS    NA                   NA
# ESTU_INSE_INDIVIDUAL           1                   NA
# ESTU_NSE_ESTABLECIMIENTO      NA                    1
# PERCENTIL_C_NATURALES         NA                   NA
# PERCENTIL_GLOBAL              NA                   NA
# PERCENTIL_INGLES              NA                   NA
# PERCENTIL_LECTURA_CRITICA     NA                   NA
# PERCENTIL_MATEMATICAS         NA                   NA
# PERCENTIL_SOCIALES_CIUDADANAS NA                   NA
# PERIODO                       NA                   NA
# PUNT_C_NATURALES              NA                   NA
# PUNT_GLOBAL                   NA                   NA
# PUNT_INGLES                   NA                   NA
# PUNT_LECTURA_CRITICA          NA                   NA
# PUNT_MATEMATICAS              NA                   NA
# PUNT_SOCIALES_CIUDADANAS      NA                   NA
#                               PERCENTIL_C_NATURALES PERCENTIL_GLOBAL
# DESEMP_C_NATURALES             0.906                 0.830
# DESEMP_LECTURA_CRITICA         0.682                 0.811
# DESEMP_MATEMATICAS             0.730                 0.830
# DESEMP_SOCIALES_CIUDADANAS     0.740                 0.847
# ESTU_INSE_INDIVIDUAL              NA                    NA
# ESTU_NSE_ESTABLECIMIENTO          NA                    NA
# PERCENTIL_C_NATURALES          1.000                 0.914
# PERCENTIL_GLOBAL               0.914                 1.000
# PERCENTIL_INGLES               0.664                 0.751
# PERCENTIL_LECTURA_CRITICA      0.750                 0.896
# PERCENTIL_MATEMATICAS          0.800                 0.908
# PERCENTIL_SOCIALES_CIUDADANAS  0.798                 0.917
# PERIODO                       -0.070                -0.073
# PUNT_C_NATURALES               0.980                 0.898
# PUNT_GLOBAL                    0.901                 0.981
# PUNT_INGLES                    0.657                 0.737
# PUNT_LECTURA_CRITICA           0.745                 0.885
# PUNT_MATEMATICAS               0.794                 0.897
# PUNT_SOCIALES_CIUDADANAS       0.790                 0.904
#                               PERCENTIL_INGLES PERCENTIL_LECTURA_CRITICA
# DESEMP_C_NATURALES             0.608            0.685
# DESEMP_LECTURA_CRITICA         0.590            0.900
# DESEMP_MATEMATICAS             0.592            0.680
# DESEMP_SOCIALES_CIUDADANAS     0.608            0.746
# ESTU_INSE_INDIVIDUAL              NA               NA
# ESTU_NSE_ESTABLECIMIENTO          NA               NA
# PERCENTIL_C_NATURALES          0.664            0.750
# PERCENTIL_GLOBAL               0.751            0.896
# PERCENTIL_INGLES               1.000            0.647
# PERCENTIL_LECTURA_CRITICA      0.647            1.000
# PERCENTIL_MATEMATICAS          0.649            0.742
# PERCENTIL_SOCIALES_CIUDADANAS  0.650            0.806
# PERIODO                       -0.073           -0.068
# PUNT_C_NATURALES               0.660            0.741
# PUNT_GLOBAL                    0.751            0.883
# PUNT_INGLES                    0.945            0.641
# PUNT_LECTURA_CRITICA           0.644            0.982
# PUNT_MATEMATICAS               0.649            0.737
# PUNT_SOCIALES_CIUDADANAS       0.649            0.796
#                               PERCENTIL_MATEMATICAS
# DESEMP_C_NATURALES             0.729
# DESEMP_LECTURA_CRITICA         0.675
# DESEMP_MATEMATICAS             0.912
# DESEMP_SOCIALES_CIUDADANAS     0.701
# ESTU_INSE_INDIVIDUAL              NA
# ESTU_NSE_ESTABLECIMIENTO          NA
# PERCENTIL_C_NATURALES          0.800
# PERCENTIL_GLOBAL               0.908
# PERCENTIL_INGLES               0.649
# PERCENTIL_LECTURA_CRITICA      0.742
# PERCENTIL_MATEMATICAS          1.000
# PERCENTIL_SOCIALES_CIUDADANAS  0.755
# PERIODO                       -0.071
# PUNT_C_NATURALES               0.790
# PUNT_GLOBAL                    0.895
# PUNT_INGLES                    0.641
# PUNT_LECTURA_CRITICA           0.737
# PUNT_MATEMATICAS               0.983
# PUNT_SOCIALES_CIUDADANAS       0.749
#                               PERCENTIL_SOCIALES_CIUDADANAS PERIODO
# DESEMP_C_NATURALES             0.726                        -0.156
# DESEMP_LECTURA_CRITICA         0.730                        -0.126
# DESEMP_MATEMATICAS             0.689                        -0.133
# DESEMP_SOCIALES_CIUDADANAS     0.920                        -0.146
# ESTU_INSE_INDIVIDUAL              NA                            NA
# ESTU_NSE_ESTABLECIMIENTO          NA                            NA
# PERCENTIL_C_NATURALES          0.798                        -0.070
# PERCENTIL_GLOBAL               0.917                        -0.073
# PERCENTIL_INGLES               0.650                        -0.073
# PERCENTIL_LECTURA_CRITICA      0.806                        -0.068
# PERCENTIL_MATEMATICAS          0.755                        -0.071
# PERCENTIL_SOCIALES_CIUDADANAS  1.000                        -0.064
# PERIODO                       -0.064                         1.000
# PUNT_C_NATURALES               0.786                        -0.171
# PUNT_GLOBAL                    0.903                        -0.181
# PUNT_INGLES                    0.645                        -0.256
# PUNT_LECTURA_CRITICA           0.796                        -0.139
# PUNT_MATEMATICAS               0.749                        -0.153
# PUNT_SOCIALES_CIUDADANAS       0.981                        -0.157
#                               PUNT_C_NATURALES PUNT_GLOBAL PUNT_INGLES
# DESEMP_C_NATURALES             0.919            0.843       0.628
# DESEMP_LECTURA_CRITICA         0.688            0.820       0.606
# DESEMP_MATEMATICAS             0.735            0.835       0.601
# DESEMP_SOCIALES_CIUDADANAS     0.747            0.858       0.632
# ESTU_INSE_INDIVIDUAL              NA               NA          NA
# ESTU_NSE_ESTABLECIMIENTO          NA               NA          NA
# PERCENTIL_C_NATURALES          0.980            0.901       0.657
# PERCENTIL_GLOBAL               0.898            0.981       0.737
# PERCENTIL_INGLES               0.660            0.751       0.945
# PERCENTIL_LECTURA_CRITICA      0.741            0.883       0.641
# PERCENTIL_MATEMATICAS          0.790            0.895       0.641
# PERCENTIL_SOCIALES_CIUDADANAS  0.786            0.903       0.645
# PERIODO                       -0.171           -0.181      -0.256
# PUNT_C_NATURALES               1.000            0.916       0.686
# PUNT_GLOBAL                    0.916            1.000       0.779
# PUNT_INGLES                    0.686            0.779       1.000
# PUNT_LECTURA_CRITICA           0.753            0.897       0.663
# PUNT_MATEMATICAS               0.805            0.912       0.670
# PUNT_SOCIALES_CIUDADANAS       0.800            0.919       0.675
#                               PUNT_LECTURA_CRITICA PUNT_MATEMATICAS
# DESEMP_C_NATURALES             0.694                0.741
# DESEMP_LECTURA_CRITICA         0.913                0.683
# DESEMP_MATEMATICAS             0.686                0.920
# DESEMP_SOCIALES_CIUDADANAS     0.752                0.710
# ESTU_INSE_INDIVIDUAL              NA                   NA
# ESTU_NSE_ESTABLECIMIENTO          NA                   NA
# PERCENTIL_C_NATURALES          0.745                0.794
# PERCENTIL_GLOBAL               0.885                0.897
# PERCENTIL_INGLES               0.644                0.649
# PERCENTIL_LECTURA_CRITICA      0.982                0.737
# PERCENTIL_MATEMATICAS          0.737                0.983
# PERCENTIL_SOCIALES_CIUDADANAS  0.796                0.749
# PERIODO                       -0.139               -0.153
# PUNT_C_NATURALES               0.753                0.805
# PUNT_GLOBAL                    0.897                0.912
# PUNT_INGLES                    0.663                0.670
# PUNT_LECTURA_CRITICA           1.000                0.746
# PUNT_MATEMATICAS               0.746                1.000
# PUNT_SOCIALES_CIUDADANAS       0.804                0.760
#                               PUNT_SOCIALES_CIUDADANAS
# DESEMP_C_NATURALES             0.737
# DESEMP_LECTURA_CRITICA         0.736
# DESEMP_MATEMATICAS             0.695
# DESEMP_SOCIALES_CIUDADANAS     0.930
# ESTU_INSE_INDIVIDUAL              NA
# ESTU_NSE_ESTABLECIMIENTO          NA
# PERCENTIL_C_NATURALES          0.790
# PERCENTIL_GLOBAL               0.904
# PERCENTIL_INGLES               0.649
# PERCENTIL_LECTURA_CRITICA      0.796
# PERCENTIL_MATEMATICAS          0.749
# PERCENTIL_SOCIALES_CIUDADANAS  0.981
# PERIODO                       -0.157
# PUNT_C_NATURALES               0.800
# PUNT_GLOBAL                    0.919
# PUNT_INGLES                    0.675
# PUNT_LECTURA_CRITICA           0.804
# PUNT_MATEMATICAS               0.760
# PUNT_SOCIALES_CIUDADANAS       1.000

# %%
# Combine multiple plots
par(mfrow=c(2,2))

# Histograms and density plots
for(i in names(icfes[, ind])){
    hist(icfes[[i]], main=i)
}

for(i in names(icfes[, ind])){
    plot(density(icfes[[i]]), main=i)
}
# Out:
# Plot with title “DESEMP_SOCIALES_CIUDADANAS”
# Plot with title “PERCENTIL_GLOBAL”
# Plot with title “PERCENTIL_SOCIALES_CIUDADANAS”
# Plot with title “PUNT_INGLES”
# Error in density.default(icfes[[i]]): 'x' contains missing values
# Traceback:
#
# 1. plot(density(icfes[[i]]), main = i)
# 2. density(icfes[[i]])
# 3. density.default(icfes[[i]])
# 4. stop("'x' contains missing values")
# Plot with title “DESEMP_C_NATURALES”
# Plot with title “DESEMP_SOCIALES_CIUDADANAS”

# %%
# Combine multiple plots
par(mfrow=c(2,2))

for(i in names(icfes[, ind])){
  boxplot(icfes[[i]], main=i)
}
# Out:
# Plot with title “DESEMP_SOCIALES_CIUDADANAS”
# Plot with title “PERCENTIL_GLOBAL”
# Plot with title “PERCENTIL_SOCIALES_CIUDADANAS”
# Plot with title “PUNT_INGLES”
# Plot with title “PUNT_SOCIALES_CIUDADANAS”
