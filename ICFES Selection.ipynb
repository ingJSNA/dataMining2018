# %%
import pandas as pd

# %%
# Read and combine files
p20171 = pd.read_csv("./data/ICFES/SB11-20171-RGSTRO-CLFCCN-V1-0.zip", sep="¬", engine="python")

p20172 = pd.read_csv("./data/ICFES/SB11-20172-RGSTRO-CLFCCN-V1-0.zip", sep="¬", engine="python")

# Concar the two periods
icfes = pd.concat([p20171, p20172], ignore_index=True)

# %%
# Drop ID columns
icfes.drop(columns=['ESTU_ESTUDIANTE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO', 'COLE_CODIGO_ICFES',
                   #'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_NOMBRE_SEDE', 
                    'COLE_COD_MCPIO_UBICACION', 
                    'COLE_COD_DEPTO_UBICACION', 'ESTU_COD_MCPIO_PRESENTACION', 'ESTU_COD_DEPTO_PRESENTACION',
                   'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_COD_DANE_SEDE'],
          inplace=True, errors='ignore')

icfes.head()
# Out:
#   COLE_AREA_UBICACION COLE_BILINGUE COLE_CALENDARIO      COLE_CARACTER  \
# 0              URBANO             N               B  TÉCNICO/ACADÉMICO
# 1              URBANO           NaN               B                NaN
# 2              URBANO             S               B          ACADÉMICO
# 3              URBANO             S               B          ACADÉMICO
# 4              URBANO             S               B          ACADÉMICO
#
#   COLE_DEPTO_UBICACION COLE_GENERO COLE_JORNADA COLE_MCPIO_UBICACION  \
# 0                VALLE       MIXTO          NaN                 CALI
# 1                CAUCA       MIXTO          NaN              POPAYAN
# 2                VALLE       MIXTO          NaN                 CALI
# 3                VALLE       MIXTO          NaN                 CALI
# 4                VALLE       MIXTO          NaN                 CALI
#
#   COLE_NATURALEZA         COLE_NOMBRE_ESTABLECIMIENTO  \
# 0      NO OFICIAL  COLEGIO PARROQIAL SANTIAGO APOSTOL
# 1      NO OFICIAL              COLEGIO CESCO BILINGÜE
# 2      NO OFICIAL                         COL BOLIVAR
# 3      NO OFICIAL                         COL BOLIVAR
# 4      NO OFICIAL                         COL BOLIVAR
#
#             ...            PERCENTIL_LECTURA_CRITICA PERCENTIL_MATEMATICAS  \
# 0           ...                                   15                     4
# 1           ...                                   78                    62
# 2           ...                                   91                    99
# 3           ...                                   96                    96
# 4           ...                                   38                    35
#
#    PERCENTIL_SOCIALES_CIUDADANAS PERIODO  PUNT_C_NATURALES  PUNT_GLOBAL  \
# 0                              1   20171                35          177
# 1                             85   20171                66          326
# 2                             76   20171                70          378
# 3                            100   20171                72          389
# 4                             63   20171                52          281
#
#    PUNT_INGLES PUNT_LECTURA_CRITICA PUNT_MATEMATICAS PUNT_SOCIALES_CIUDADANAS
# 0           45                   44               31                       28
# 1           55                   67               61                       70
# 2          100                   72               86                       66
# 3           85                   75               79                       83
# 4           80                   54               50                       61
#
# [5 rows x 79 columns]

# %%
icfes['FAMI_TIENEINTERNET'].describe(include='all')
# Out:
# count     12648
# unique        2
# top          SI
# freq      12127
# Name: FAMI_TIENEINTERNET, dtype: object

# %%
icfes.dtypes
# Out:
# COLE_AREA_UBICACION               object
# COLE_BILINGUE                     object
# COLE_CALENDARIO                   object
# COLE_CARACTER                     object
# COLE_DEPTO_UBICACION              object
# COLE_GENERO                       object
# COLE_JORNADA                      object
# COLE_MCPIO_UBICACION              object
# COLE_NATURALEZA                   object
# COLE_NOMBRE_ESTABLECIMIENTO       object
# COLE_NOMBRE_SEDE                  object
# COLE_SEDE_PRINCIPAL               object
# DESEMP_C_NATURALES                 int64
# DESEMP_INGLES                     object
# DESEMP_LECTURA_CRITICA             int64
# DESEMP_MATEMATICAS                 int64
# DESEMP_SOCIALES_CIUDADANAS         int64
# ESTU_CONSECUTIVO                  object
# ESTU_DEDICACIONINTERNET           object
# ESTU_DEDICACIONLECTURADIARIA      object
# ESTU_DEPTO_PRESENTACION           object
# ESTU_DEPTO_RESIDE                 object
# ESTU_ESTADOINVESTIGACION          object
# ESTU_ETNIA                        object
# ESTU_FECHANACIMIENTO              object
# ESTU_GENERO                       object
# ESTU_HORASSEMANATRABAJA           object
# ESTU_INSE_INDIVIDUAL             float64
# ESTU_MCPIO_PRESENTACION           object
# ESTU_MCPIO_RESIDE                 object
#                                   ...
# FAMI_PERSONASHOGAR                object
# FAMI_SITUACIONECONOMICA           object
# FAMI_SITUACION_ECONOMICA          object
# FAMI_TIENEAUTOMOVIL               object
# FAMI_TIENECOMPUTADOR              object
# FAMI_TIENECONSOLAVIDEOJUEGOS      object
# FAMI_TIENEHORNOMICROOGAS          object
# FAMI_TIENEINTERNET                object
# FAMI_TIENELAVADORA                object
# FAMI_TIENEMOTOCICLETA             object
# FAMI_TIENESERVICIOTV              object
# FAMI_TIENE_CONSOLAVIDEOJUEGOS     object
# FAMI_TIENE_SERVICIOTV             object
# FAMI_TRABAJOLABORMADRE            object
# FAMI_TRABAJOLABORPADRE            object
# FAMI_TRABAJOLABOR_MADRE           object
# FAMI_TRABAJOLABOR_PADRE           object
# PERCENTIL_C_NATURALES              int64
# PERCENTIL_GLOBAL                   int64
# PERCENTIL_INGLES                   int64
# PERCENTIL_LECTURA_CRITICA          int64
# PERCENTIL_MATEMATICAS              int64
# PERCENTIL_SOCIALES_CIUDADANAS      int64
# PERIODO                            int64
# PUNT_C_NATURALES                   int64
# PUNT_GLOBAL                        int64
# PUNT_INGLES                        int64
# PUNT_LECTURA_CRITICA               int64
# PUNT_MATEMATICAS                   int64
# PUNT_SOCIALES_CIUDADANAS           int64
# Length: 79, dtype: object

# %%
# Replace extrange characters in string values
icfes.replace(to_replace=('\"', '`', '\''), value=('', ' ', ' '), regex=True, inplace=True)


#icfes[icfes['COLE_NOMBRE_ESTABLECIMIENTO'].str.contains("IDEBIC")].iloc[0:5, 14:]

# %%
icfes.to_csv("./data/ICFES/icfes.csv", index=False, encoding="utf-8")

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

icfes.select_dtypes(include=numerics).to_csv("./data/ICFES/icfes_num.csv", index=False, encoding="utf-8")
